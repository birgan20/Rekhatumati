# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:/Users/Dell/OneDrive/Documents/Python/Myproject/usa_rain_prediction_dataset_2024_2025.csv")
data
# Out:
#              Date         Location  Temperature   Humidity  Wind Speed  \
# 0      01-01-2024         New York    87.524795  75.655455   28.379506
# 1      02-01-2024         New York    83.259325  28.712617   12.436433
# 2      03-01-2024         New York    80.943050  64.740043   14.184831
# 3      04-01-2024         New York    78.097552  59.738984   19.444029
# 4      05-01-2024         New York    37.059963  34.766784    3.689661
# ...           ...              ...          ...        ...         ...
# 73095  27-12-2025  Washington D.C.    40.614393  65.099438   28.778327
# 73096  28-12-2025  Washington D.C.    52.641643  30.610525   12.282890
# 73097  29-12-2025  Washington D.C.    56.492591  96.740232    2.894762
# 73098  30-12-2025  Washington D.C.    65.748956  63.900004   24.632400
# 73099  31-12-2025  Washington D.C.    54.648609  80.812021   22.722505
#
#        Precipitation  Cloud Cover     Pressure  Rain Tomorrow
# ...

# %%
data.head()
# Out:
#          Date  Location  Temperature   Humidity  Wind Speed  Precipitation  \
# 0  01-01-2024  New York    87.524795  75.655455   28.379506       0.000000
# 1  02-01-2024  New York    83.259325  28.712617   12.436433       0.526995
# 2  03-01-2024  New York    80.943050  64.740043   14.184831       0.916884
# 3  04-01-2024  New York    78.097552  59.738984   19.444029       0.094134
# 4  05-01-2024  New York    37.059963  34.766784    3.689661       1.361272
#
#    Cloud Cover     Pressure  Rain Tomorrow
# 0    69.617966  1026.030278            0.0
# 1    41.606048   995.962065            0.0
# 2    77.364763   980.796739            1.0
# 3    52.541196   979.012163            0.0
# 4    85.584000  1031.790859            0.0

# %%
data.tail()
# Out:
#              Date         Location  Temperature   Humidity  Wind Speed  \
# 73095  27-12-2025  Washington D.C.    40.614393  65.099438   28.778327
# 73096  28-12-2025  Washington D.C.    52.641643  30.610525   12.282890
# 73097  29-12-2025  Washington D.C.    56.492591  96.740232    2.894762
# 73098  30-12-2025  Washington D.C.    65.748956  63.900004   24.632400
# 73099  31-12-2025  Washington D.C.    54.648609  80.812021   22.722505
#
#        Precipitation  Cloud Cover     Pressure  Rain Tomorrow
# 73095       0.000000    54.168514   977.083747            0.0
# 73096       0.871000    22.068055   980.591674            0.0
# 73097       1.191956    52.336048  1016.469174            1.0
# 73098       0.483421    76.785280  1032.396146            1.0
# 73099       0.151903    19.674960   974.835534            0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73100 entries, 0 to 73099
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           73100 non-null  object
#  1   Location       73100 non-null  object
#  2   Temperature    73084 non-null  float64
#  3   Humidity       73086 non-null  float64
#  4   Wind Speed     73088 non-null  float64
#  5   Precipitation  73088 non-null  float64
#  6   Cloud Cover    73085 non-null  float64
#  7   Pressure       73087 non-null  float64
#  8   Rain Tomorrow  73093 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 5.0+ MB

# %%
data.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation   Cloud Cover  \
# count  73084.000000  73086.000000  73088.000000   73088.000000  73085.000000
# mean      65.182374     59.874897     15.017680       0.390613     54.944714
# std       20.205945     23.065798      8.668742       0.474838     25.983027
# min       30.000766     20.000272      0.000712       0.000000     10.000856
# 25%       47.678567     39.801093      7.484962       0.000000     32.319865
# 50%       65.295369     59.885839     15.102495       0.196863     55.014087
# 75%       82.636570     79.837318     22.551580       0.673166     77.419400
# max       99.997393     99.999025     29.999017       3.078090     99.998957
#
#            Pressure  Rain Tomorrow
# count  73087.000000   73093.000000
# mean    1005.175947       0.220390
# std       20.204274       0.414513
# min      970.000919       0.000000
# 25%      987.697236       0.000000
# 50%     1005.283686       0.000000
# ...

# %%
missingvalue=data.isnull()
missingvalue
# Out:
#         Date  Location  Temperature  Humidity  Wind Speed  Precipitation  \
# 0      False     False        False     False       False          False
# 1      False     False        False     False       False          False
# 2      False     False        False     False       False          False
# 3      False     False        False     False       False          False
# 4      False     False        False     False       False          False
# ...      ...       ...          ...       ...         ...            ...
# 73095  False     False        False     False       False          False
# 73096  False     False        False     False       False          False
# 73097  False     False        False     False       False          False
# 73098  False     False        False     False       False          False
# 73099  False     False        False     False       False          False
#
#        Cloud Cover  Pressure  Rain Tomorrow
# 0            False     False          False
# ...

# %%
missingvalue=data.isnull().sum()
missingvalue
# Out:
# Date              0
# Location          0
# Temperature      16
# Humidity         14
# Wind Speed       12
# Precipitation    12
# Cloud Cover      15
# Pressure         13
# Rain Tomorrow     7
# dtype: int64

# %%
x1=data["Temperature"].mean()
x1
# Out:
# 65.18237448843674

# %%
x2=data["Humidity"].mean()
x2
# Out:
# 59.87489682644815

# %%
x3=data["Wind Speed"].mean()
x3
# Out:
# 15.01768049568772

# %%
x4=data["Precipitation"].mean()
x4
# Out:
# 0.3906134323076702

# %%
x5=data["Cloud Cover"].mean()
x5
# Out:
# 54.944713936226314

# %%
x6=data["Pressure"].mean()
x6
# Out:
# 1005.175947071564

# %%
x7=data["Rain Tomorrow"].mode()
x7
# Out:
# 0    0.0
# Name: Rain Tomorrow, dtype: float64

# %%
data["Temperature"].fillna(x1, inplace = True)
data["Humidity"].fillna(x2, inplace = True)
data["Wind Speed"].fillna(x3, inplace = True)
data["Precipitation"].fillna(x4, inplace = True)
data["Cloud Cover"].fillna(x5, inplace = True)
data["Pressure"].fillna(x6, inplace = True)
data["Rain Tomorrow"].fillna(0.0, inplace = True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11756\1503343428.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Temperature"].fillna(x1, inplace = True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11756\1503343428.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
data["Rain Tomorrow"] = label_encoder.fit_transform(data["Rain Tomorrow"])
data["Rain Tomorrow"]
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 73095    0
# 73096    0
# 73097    1
# 73098    1
# 73099    0
# Name: Rain Tomorrow, Length: 73100, dtype: int64

# %%
missingvalue = data.isnull().sum()
missingvalue
# Out:
# Date             0
# Location         0
# Temperature      0
# Humidity         0
# Wind Speed       0
# Precipitation    0
# Cloud Cover      0
# Pressure         0
# Rain Tomorrow    0
# dtype: int64

# %%
data
# Out:
#              Date         Location  Temperature   Humidity  Wind Speed  \
# 0      01-01-2024         New York    87.524795  75.655455   28.379506
# 1      02-01-2024         New York    83.259325  28.712617   12.436433
# 2      03-01-2024         New York    80.943050  64.740043   14.184831
# 3      04-01-2024         New York    78.097552  59.738984   19.444029
# 4      05-01-2024         New York    37.059963  34.766784    3.689661
# ...           ...              ...          ...        ...         ...
# 73095  27-12-2025  Washington D.C.    40.614393  65.099438   28.778327
# 73096  28-12-2025  Washington D.C.    52.641643  30.610525   12.282890
# 73097  29-12-2025  Washington D.C.    56.492591  96.740232    2.894762
# 73098  30-12-2025  Washington D.C.    65.748956  63.900004   24.632400
# 73099  31-12-2025  Washington D.C.    54.648609  80.812021   22.722505
#
#        Precipitation  Cloud Cover     Pressure  Rain Tomorrow
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data1=data.drop(["Date","Location"],axis=1)
correlation_matrix = data1.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
X=data.drop(["Date","Location","Rain Tomorrow"],axis=1)
Y=data["Rain Tomorrow"]

# %%
X
# Out:
#        Temperature   Humidity  Wind Speed  Precipitation  Cloud Cover  \
# 0        87.524795  75.655455   28.379506       0.000000    69.617966
# 1        83.259325  28.712617   12.436433       0.526995    41.606048
# 2        80.943050  64.740043   14.184831       0.916884    77.364763
# 3        78.097552  59.738984   19.444029       0.094134    52.541196
# 4        37.059963  34.766784    3.689661       1.361272    85.584000
# ...            ...        ...         ...            ...          ...
# 73095    40.614393  65.099438   28.778327       0.000000    54.168514
# 73096    52.641643  30.610525   12.282890       0.871000    22.068055
# 73097    56.492591  96.740232    2.894762       1.191956    52.336048
# 73098    65.748956  63.900004   24.632400       0.483421    76.785280
# 73099    54.648609  80.812021   22.722505       0.151903    19.674960
#
#           Pressure
# 0      1026.030278
# 1       995.962065
# 2       980.796739
# 3       979.012163
# 4      1031.790859
# ...

# %%
Y
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 73095    0
# 73096    0
# 73097    1
# 73098    1
# 73099    0
# Name: Rain Tomorrow, Length: 73100, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73100 entries, 0 to 73099
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           73100 non-null  object
#  1   Location       73100 non-null  object
#  2   Temperature    73100 non-null  float64
#  3   Humidity       73100 non-null  float64
#  4   Wind Speed     73100 non-null  float64
#  5   Precipitation  73100 non-null  float64
#  6   Cloud Cover    73100 non-null  float64
#  7   Pressure       73100 non-null  float64
#  8   Rain Tomorrow  73100 non-null  int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 5.0+ MB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.head()
# Out:
#        Temperature   Humidity  Wind Speed  Precipitation  Cloud Cover  \
# 12934    94.400847  30.101788   27.125792       0.000000    22.156541
# 19473    42.347508  72.291153   11.864686       0.000000    78.616367
# 13001    61.599022  69.579675   25.963909       0.987198    65.356192
# 26535    92.764507  90.944364   16.475073       0.000000    66.736579
# 8236     42.108787  70.881935    1.662974       0.000000    22.626918
#
#           Pressure
# 12934   996.493324
# 19473   990.436746
# 13001   979.811993
# 26535  1034.282752
# 8236    998.666143

# %%
Y_train.head()
# Out:
# 12934    0
# 19473    0
# 13001    1
# 26535    0
# 8236     0
# Name: Rain Tomorrow, dtype: int64

# %%
X_test.head()
# Out:
#        Temperature   Humidity  Wind Speed  Precipitation  Cloud Cover  \
# 66127    48.052607  60.603176   24.946214       0.000000    49.344512
# 43485    76.409199  87.441871   14.162805       0.060954    86.571375
# 34304    35.668016  68.053619   18.195591       0.942199    31.233485
# 34317    63.633611  83.717856   23.486385       0.259003    10.990360
# 38631    51.459740  82.835612   25.238400       0.087099    17.705639
#
#           Pressure
# 66127  1020.133430
# 43485  1018.283834
# 34304  1020.116697
# 34317  1001.981662
# 38631   976.618916

# %%
Y_test.head()
# Out:
# 66127    0
# 43485    0
# 34304    1
# 34317    0
# 38631    0
# Name: Rain Tomorrow, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
data["Rain Tomorrow"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([0, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


# Generate confusion matrix
cm = confusion_matrix(Y_test, Y_pred)

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1,])  # Change labels as needed
disp.plot(cmap=plt.cm.Blues)  # You can choose another colormap if desired

# Customize plot if needed
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(Y_test, Y_pred)
accuracy
# Out:
# 0.9077975376196991

# %%
import joblib

joblib.dump(model,'newfile.pkl')
# Out:
# ['newfile.pkl']

# %%
import joblib

# Load the model from the file
loaded_model = joblib.load('newfile.pkl')

# Make predictions with the loaded model
Y_pred = loaded_model.predict([[80.943050,64.740043,14.184831,0.916884,77.364763,980.796739]])
print(Y_pred)
# Out:
# [1]
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
